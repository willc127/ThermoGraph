# %%
import tabula
import pandas as pd

# %%
pdf_path = "perry.pdf"

dfs = tabula.read_pdf(pdf_path, stream=True, pages="172-178")
# read_pdf returns list of DataFrames
print(len(dfs))
# Out:
# 7

# %%
dfs[0]
# Out:
#    Unnamed: 0 Cmpd.           Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 0         Eqn   no.                 Name    Formula          CAS   Mol. wt.
# 1         100     1         Acetaldehyde      C2H4O      75-07-0   44.05256
# 2         100     2            Acetamide     C2H5NO      60-35-5    59.0672
# 3         100     3          Acetic acid     C2H4O2      64-19-7     60.052
# 4         100     4     Acetic anhydride     C4H6O3     108-24-7  102.08864
# 5         100     5              Acetone      C3H6O      67-64-1   58.07914
# 6         100     6         Acetonitrile      C2H3N      75-05-8    41.0519
# 7         100     7            Acetylene       C2H2      74-86-2   26.03728
# 8         100     8             Acrolein      C3H4O     107-02-8   56.06326
# 9         100     9         Acrylic acid     C3H4O2      79-10-7   72.06266
# 10        100    10        Acrylonitrile      C3H3N     107-13-1    53.0626
# ...
